# %%
'''

# TUTORIAL 1
# GUI - Graphical User Interface
# Tkinter - TK Interface
#Importamos el módulo de tkinter
import tkinter as tk
#Importamos el módulo del tema de tkinter
from tkinter import ttk

#Creamos un objeto usando la clase Tk
ventana=tk.Tk()

#Modificamos el tamaño de la ventana (píxeles)
ventana.geometry('600x400')

#Cambiamos el nombre de la ventana
ventana.title('ProSim2')

#Cambiamos el ícono de la aplicación
ventana.iconbitmap('C:/Users/josea/Documents/Servicio social/ProSim2.ico')

#Creamos un método evento_click
def evento_click():
    boton1.config(text='Botón presionado')
    #config permite modificar la configuración del botón
    print('Ejecución del evento click')
    #Creamos un nuevo botón y lo mostramos
    boton2=ttk.Button(ventana, text='Nuevo botón')
    boton2.pack()

#Creamos un botón (widget), que se mostrará en la ventana
boton1=ttk.Button(ventana, text='Dar click', command=evento_click)
#El parámetro command especifica lo que se hará al dar click en el botón
#No lleva paréntesis, porque no lo mandamos a llamar como tal
#Utilizamos el pack layout manager para mostrar el botón de la ventana
boton1.pack()

#Iniciamos la ventana (Esta línea la ejecutamos al final)
#Si la ejecutamos antes, no se muestrarn los cambios anteriores
ventana.mainloop()

'''
# Out:
# "\n\n# TUTORIAL 1\n# GUI - Graphical User Interface\n# Tkinter - TK Interface\n#Importamos el módulo de tkinter\nimport tkinter as tk\n#Importamos el módulo del tema de tkinter\nfrom tkinter import ttk\n\n#Creamos un objeto usando la clase Tk\nventana=tk.Tk()\n\n#Modificamos el tamaño de la ventana (píxeles)\nventana.geometry('600x400')\n\n#Cambiamos el nombre de la ventana\nventana.title('ProSim2')\n\n#Cambiamos el ícono de la aplicación\nventana.iconbitmap('C:/Users/josea/Documents/Servicio social/ProSim2.ico')\n\n#Creamos un método evento_click\ndef evento_click():\n    boton1.config(text='Botón presionado')\n    #config permite modificar la configuración del botón\n    print('Ejecución del evento click')\n    #Creamos un nuevo botón y lo mostramos\n    boton2=ttk.Button(ventana, text='Nuevo botón')\n    boton2.pack()\n\n#Creamos un botón (widget), que se mostrará en la ventana\nboton1=ttk.Button(ventana, text='Dar click', command=evento_click)\n#El parámetro command especifica lo
# ...

# %%
'''
# Tutorial 2
#Importamos el módulo de tkinter
import tkinter as tk
#Importamos el módulo del tema de tkinter
from tkinter import ttk

#Creamos un objeto usando la clase Tk
ventana=tk.Tk()

#Modificamos el tamaño de la ventana (píxeles)
ventana.geometry('600x400')

#Cambiamos el nombre de la ventana
ventana.title('ProSim2: Manejo de Grid')

#Cambiamos el ícono de la aplicación
ventana.iconbitmap('C:/Users/josea/Documents/Servicio social/ProSim2.ico')

#Configurar el grid
ventana.rowconfigure(0, weight=2)
ventana.rowconfigure(1, weight=10)
ventana.columnconfigure(0, weight=1)
ventana.columnconfigure(1, weight=5)
'''Tamaño en proporción que utilizará el primer renglón
el primer parámetro es el índice, weight es la proporción'''

#Métodos de los eventos
def evento1():
    boton1.config(text='Boton 1 presionado')
def evento2():
    boton2.config(text='Boton 2 presionado')
def evento3():
    boton3.config(text='Boton 3 presionado')
def evento4():
    boton4.config(text='Boton 4 presionado')

#Definimos dos botones
boton1=ttk.Button(ventana, text='Boton 1', command=evento1)
boton1.grid(row=0, column=0, sticky='NSWE')
'''N(arriba), E(derecha), S(abajo), W(izquierda)
NS: Se expande arriba hacia abajo
WE: Se expande de izquierda a derecha'''
#############################################################
boton2=ttk.Button(ventana, text='Boton 2', command=evento2)
boton2.grid(row=1, column=0, sticky='NSWE')
#Con sticky se queda fijo, sin necesidad de centrarse
#Grid sirve para posicionar el botón

#Boton 3
boton3=ttk.Button(ventana, text='Botón 3', command=evento3)
boton3.grid(row=0, column=1, sticky='NSWE')

#Boton 4
boton4=ttk.Button(ventana, text='Boton 4', command=evento4)
boton4.grid(row=1, column=1, sticky='NSWE')



#Iniciamos la ventana (Esta línea la ejecutamos al final)
#Si la ejecutamos antes, no se muestrarn los cambios anteriores
ventana.mainloop()
'''

# %%
'''
# Tutorial 3
#Importamos el módulo de tkinter
import tkinter as tk
#Importamos el módulo del tema de tkinter
from tkinter import ttk

#Creamos un objeto usando la clase Tk
ventana=tk.Tk()

#Modificamos el tamaño de la ventana (píxeles)
ventana.geometry('600x400')

#Cambiamos el nombre de la ventana
ventana.title('ProSim2: Manejo de Grid')

#Cambiamos el ícono de la aplicación
ventana.iconbitmap('C:/Users/josea/Documents/Servicio social/ProSim2.ico')

#Configurar el grid
ventana.rowconfigure(0, weight=2)
ventana.rowconfigure(1, weight=10)
ventana.columnconfigure(0, weight=1)
ventana.columnconfigure(1, weight=5)
'''Tamaño en proporción que utilizará el primer renglón
el primer parámetro es el índice, weight es la proporción'''

#Métodos de los eventos
def evento1():
    boton1.config(text='Boton 1 presionado')
def evento2():
    boton2.config(text='Boton 2 presionado')
def evento3():
    boton3.config(text='Boton 3 presionado')
def evento4():
    boton4.config(text='Boton 4 presionado', fg='blue', relief=tk.GROOVE,
                 bg='yellow')
    '''fg (foreground) cambia el color de la fuente (letras)
    relief cambia el contorno del botón
    bg (background) cambia el color del fondo'''

#Definimos dos botones
boton1=ttk.Button(ventana, text='Boton 1', command=evento1)
boton1.grid(row=0, column=0, sticky='NSWE', padx=40, pady=30, ipadx=20, 
           ipady=50, columnspan=2, rowspan=2)
'''N(arriba), E(derecha), S(abajo), W(izquierda)
NS: Se expande arriba hacia abajo
WE: Se expande de izquierda a derecha
padx: Espacio en el margen externo en el eje x
columnspan: Extiende a 'n' número de columnas
rowspan: Extiende a 'n' número de filas'''
#############################################################
boton2=ttk.Button(ventana, text='Boton 2', command=evento2)
boton2.grid(row=1, column=0, sticky='NSWE')
#Con sticky se queda fijo, sin necesidad de centrarse
#Grid sirve para posicionar el botón

#Boton 3
boton3=ttk.Button(ventana, text='Botón 3', command=evento3)
boton3.grid(row=0, column=1, sticky='NSWE')

#Boton 4
#Botón con tk
boton4=tk.Button(ventana, text='Boton 4', command=evento4)
boton4.grid(row=1, column=1, sticky='NSWE')



#Iniciamos la ventana (Esta línea la ejecutamos al final)
#Si la ejecutamos antes, no se muestrarn los cambios anteriores
ventana.mainloop()
'''

# %%
'''
# Tutorial 4
#Importamos el módulo de tkinter
import tkinter as tk
#Importamos el módulo del tema de tkinter
from tkinter import ttk

#Creamos un objeto usando la clase Tk
ventana=tk.Tk()

#Modificamos el tamaño de la ventana (píxeles)
ventana.geometry('600x400')

#Cambiamos el nombre de la ventana
ventana.title('ProSim2: Manejo de Grid')

#Cambiamos el ícono de la aplicación
ventana.iconbitmap('C:/Users/josea/Documents/Servicio social/ProSim2.ico')

entrada0=ttk.Entry(ventana, width=31, justify=tk.CENTER)
entrada0.grid(row=0, column=0)

entrada1=ttk.Entry(ventana, width=31, justify=tk.CENTER, show='*')
entrada1.grid(row=1, column=0)

entrada2=ttk.Entry(ventana, width=31, justify=tk.CENTER, state=tk.DISABLED)
entrada2.grid(row=2, column=0)

'''El primer parámetro es el elemento padre
width: Es el número de caracteres
justify: justifica el texto
tk.CENTER: Al centro
tk.RIGHT: A la derecha
tk.LEFT: A la izquierda
show='*': Muestra lo que se verá cuando se escribe (como contraseña)
state=tk.DISABLED: Desabilita la entrada de texto
state=tk.NORMAL: Habilita la entrada de texto'''

#El método insert agrega un texto a nuestra caja de texto
entrada0.insert(0,'Introduce una cadena')
entrada0.insert(5,'-')
entrada0.insert(tk.END, ': ')
entrada1.insert(0,'Introduce una cadena: ')
entrada1.insert(5,'-')
entrada1.insert(tk.END, 'Wilson')
entrada1.config(state='readonly')
'''El primer parámetro es el índice donde queremos que se inserte este texto
tk.END ingresa un elemento al final de la cadena
.config(state='readonly'): Permite sólo lectura'''

#Iniciamos la ventana (Esta línea la ejecutamos al final)
#Si la ejecutamos antes, no se muestrarn los cambios anteriores
ventana.mainloop()

'''

# %%
# Tutorial 5
#Importamos el módulo de tkinter
import tkinter as tk
#Importamos el módulo del tema de tkinter
from tkinter import ttk

#Creamos un objeto usando la clase Tk
ventana=tk.Tk()

#Modificamos el tamaño de la ventana (píxeles)
ventana.geometry('600x400')

#Cambiamos el nombre de la ventana
ventana.title('ProSim2: Manejo de Grid')

#Cambiamos el ícono de la aplicación
ventana.iconbitmap('C:/Users/josea/Documents/Servicio social/ProSim2.ico')

entrada1=ttk.Entry(ventana, width=50, justify=tk.CENTER)
entrada1.grid(row=0, column=0)

'''El primer parámetro es el elemento padre
width: Es el número de caracteres
justify: justifica el texto
tk.CENTER: Al centro
tk.RIGHT: A la derecha
tk.LEFT: A la izquierda
show='*': Muestra lo que se verá cuando se escribe (como contraseña)
state=tk.DISABLED: Desabilita la entrada de texto
state=tk.NORMAL: Habilita la entrada de texto'''

#El método insert agrega un texto a nuestra caja de texto
entrada1.insert(0,'Introduce una cadena como ')
entrada1.insert(5,'-')
entrada1.insert(tk.END, 'Wilson: ')
#entrada1.config(state='readonly')
'''El primer parámetro es el índice donde queremos que se inserte este texto
tk.END ingresa un elemento al final de la cadena
.config(state='readonly'): Permite sólo lectura'''

#Método enviar
def enviar():
    print(entrada1.get())
    boton1.config(text=entrada1.get())
    #.get(): Recibe el texto
    '''
    #Eliminar el contenido
    entrada1.delete(0, tk.END) #Desde el indice cero hasta el final.
    #Seleccionar el texto de la caja'''
    entrada1.select_range(0, tk.END)#Selecciona desde el inicio al final
    #Para hacer efectiva la selección del texto
    entrada1.focus()

#Creamos un boton
boton1=ttk.Button(ventana, text='Enviar', command=enviar)
boton1.grid(row=0, column=1)

#Iniciamos la ventana (Esta línea la ejecutamos al final)
#Si la ejecutamos antes, no se muestrarn los cambios anteriores
ventana.mainloop()
# Out:
# Intro-duce una cadena como Wilson:
# Han
# Han

# %%
# Tutorial 6
#Importamos el módulo de tkinter
import tkinter as tk
#Importamos el módulo del tema de tkinter
from tkinter import ttk

#Creamos un objeto usando la clase Tk
ventana=tk.Tk()

#Modificamos el tamaño de la ventana (píxeles)
ventana.geometry('600x400')

#Cambiamos el nombre de la ventana
ventana.title('ProSim2: Manejo de Grid')

#Cambiamos el ícono de la aplicación
ventana.iconbitmap('C:/Users/josea/Documents/Servicio social/ProSim2.ico')

#Definimos una variable que podremos modificar posteriormente (set), leer(get)
entrada_var1=tk.StringVar(value='Valor por defecto')
#Variable de tipo StringVar

entrada1=ttk.Entry(ventana, width=50, textvariable=entrada_var1)
#Asocio una variable de texto a Entry por medio de la propiedad textvariable
#textvariable: Asigna texto al contenido de Entry
entrada1.grid(row=0, column=0)

'''El primer parámetro es el elemento padre
width: Es el número de caracteres
justify: justifica el texto
tk.CENTER: Al centro
tk.RIGHT: A la derecha
tk.LEFT: A la izquierda
show='*': Muestra lo que se verá cuando se escribe (como contraseña)
state=tk.DISABLED: Desabilita la entrada de texto
state=tk.NORMAL: Habilita la entrada de texto'''

'''
#El método insert agrega un texto a nuestra caja de texto
entrada1.insert(0,'Introduce una cadena como ')
entrada1.insert(5,'-')
entrada1.insert(tk.END, 'Wilson: ')
#entrada1.config(state='readonly')'''
'''El primer parámetro es el índice donde queremos que se inserte este texto
tk.END ingresa un elemento al final de la cadena
.config(state='readonly'): Permite sólo lectura'''

#Método enviar
def enviar():
    #Recuperamos la información a partir de la variable asociada con la caja de texto
    boton1.config(text=entrada_var1.get())
    #Modificación utilizamos la variable de texto y el método set
    entrada_var1.set('Cambio...')
    #Recuperarmos la información 
    print(entrada_var1.get())
    print(entrada1.get())

#Creamos un boton
boton1=ttk.Button(ventana, text='Enviar', command=enviar)
boton1.grid(row=0, column=1)

#Iniciamos la ventana (Esta línea la ejecutamos al final)
#Si la ejecutamos antes, no se muestrarn los cambios anteriores
ventana.mainloop()
# Out:
# Cambio...
# Cambio...
# Cambio...
# Cambio...
# Cambio...
# Cambio...
# Cambio...
# Cambio...

# %%
# Tutorial 7
#Importamos el módulo de tkinter
import tkinter as tk
#Importamos el módulo del tema de tkinter
from tkinter import ttk

#Creamos un objeto usando la clase Tk
ventana=tk.Tk()

#Modificamos el tamaño de la ventana (píxeles)
ventana.geometry('600x400')

#Cambiamos el nombre de la ventana
ventana.title('Manejo de componentes')

#Cambiamos el ícono de la aplicación
ventana.iconbitmap('C:/Users/josea/Documents/Servicio social/ProSim2.ico')

#Definimos una variable que podremos modificar posteriormente (set), leer(get)
entrada_var1=tk.StringVar(value='Valor por defecto')
#Variable de tipo StringVar

entrada1=ttk.Entry(ventana, width=30, textvariable=entrada_var1)
#Asocio una variable de texto a Entry por medio de la propiedad textvariable
#textvariable: Asigna texto al contenido de Entry
entrada1.grid(row=0, column=0)

'''El primer parámetro es el elemento padre
width: Es el número de caracteres
justify: justifica el texto
tk.CENTER: Al centro
tk.RIGHT: A la derecha
tk.LEFT: A la izquierda
show='*': Muestra lo que se verá cuando se escribe (como contraseña)
state=tk.DISABLED: Desabilita la entrada de texto
state=tk.NORMAL: Habilita la entrada de texto'''

'''
#El método insert agrega un texto a nuestra caja de texto
entrada1.insert(0,'Introduce una cadena como ')
entrada1.insert(5,'-')
entrada1.insert(tk.END, 'Wilson: ')
#entrada1.config(state='readonly')'''
'''El primer parámetro es el índice donde queremos que se inserte este texto
tk.END ingresa un elemento al final de la cadena
.config(state='readonly'): Permite sólo lectura'''

#Etiqueta (label)
etiqueta1=tk.Label(ventana, text='Aquí se mostrará el contenido de la caja de texto')
etiqueta1.grid(row=1, column=0, columnspan=2)
'''tk.Label: Para poner etiquetas
primer argumento: Elemento padre
text: texto
columnspan= Abarca 2 columnas'''


#Método enviar
def enviar():
    #Modfcamos el texto de label
    etiqueta1.config(text=entrada_var1.get())
   

#Creamos un botón
boton1=ttk.Button(ventana, text='Enviar', command=enviar)
boton1.grid(row=0, column=1)

#Iniciamos la ventana (Esta línea la ejecutamos al final)
#Si la ejecutamos antes, no se muestrarn los cambios anteriores
ventana.mainloop()
