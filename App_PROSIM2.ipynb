# %%
import tkinter as tk
from tkinter import ttk
#########################################################################################################################
ventana = tk.Tk()
ventana.geometry('1000x1000')
ventana.title('Menú principal')
ventana.iconbitmap('C:/Users/josea/Documents/Servicio social/ProSim2.ico')
########################################################################################################################
style = ttk.Style()# Creamos un estilo personalizado
style.configure('TButton', foreground='black', background='lightblue', font=('Arial', 12))
style.configure('TLabel', foreground='darkblue', background='white', font=('Arial', 14), justify='right')
########################################################################################################################
etiqueta1 = ttk.Label(ventana, text='     ')
etiqueta1.grid(row=10, column=10, columnspan=2)
#########################################################################################################################
def ECG():
    etiqueta1.config(text="Usted eligió: ECG onda")
    ventana_ECG = tk.Toplevel(ventana)
    ventana_ECG.geometry('800x800')
    ventana_ECG.title('ECG onda')
    
    aceptar=ttk.Button(ventana_ECG, text='Aceptar')
    aceptar.grid(row=20, column=25)
    
    etiqueta_ECG=ttk.Label(ventana_ECG, text='Tasa ECG (BPM): ')
    etiqueta_amplitud=ttk.Label(ventana_ECG, text='Amplitud (mV): ')
    etiqueta_tipo=ttk.Label(ventana_ECG, text='Tipo (Adulto/Niño): ')
    etiqueta_st=ttk.Label(ventana_ECG, text='ST: ')
    etiqueta_artefacto=ttk.Label(ventana_ECG, text='Artefacto (On/Off): ')
    #///////////////////////////////////////////////////////////////////
    etiqueta_ECG.grid(row=10, column=22, columnspan=2)
    etiqueta_ECG.configure(style='TLabel')
    
    etiqueta_amplitud.grid(row=11, column=22, columnspan=2)
    etiqueta_amplitud.configure(style='TLabel')
    
    etiqueta_tipo.grid(row=12, column=22, columnspan=2)
    etiqueta_tipo.configure(style='TLabel')
    
    etiqueta_st.grid(row=13, column=22, columnspan=2)
    etiqueta_st.configure(style='TLabel')
    
    etiqueta_artefacto.grid(row=14, column=22, columnspan=2)
    etiqueta_artefacto.configure(style='TLabel')
    #///////////////////////////////////////////////////////////////////
    entrada_ECG=ttk.Entry(ventana_ECG, width=40, textvariable='Ingresa los latidos por minuto: ')
    entrada_ECG.grid(row=10, column=25)
    
    entrada_amplitud=ttk.Entry(ventana_ECG, width=40, textvariable='Ingresa la amplitud: ')
    entrada_amplitud.grid(row=11, column=25)
    
    entrada_tipo=ttk.Entry(ventana_ECG, width=40, textvariable='Ingresa el tipo: ')
    entrada_tipo.grid(row=12, column=25)
    
    entrada_st=ttk.Entry(ventana_ECG, width=40, textvariable='Ingresa el ST: ')
    entrada_st.grid(row=13, column=25)
    
    entrada_artefacto=ttk.Entry(ventana_ECG, width=40, textvariable='Ingresa el artefacto: ')
    entrada_artefacto.grid(row=14, column=25)
      
########################################################################################################################
def arry():
    etiqueta1.config(text="Usted eligió: Arritmia")
    ventana_arry=tk.Tk()
    #Modificamos el tamaño de la ventana (píxeles)
    ventana_arry.geometry('700x700')
    #Cambiamos el nombre de la ventana
    ventana_arry.title('Arritmia')
########################################################################################################################    
def temp():
    etiqueta1.config(text="Usted eligió: Temperatura")
    ventana_temp=tk.Tk()
    #Modificamos el tamaño de la ventana (píxeles)
    ventana_temp.geometry('700x700')
    #Cambiamos el nombre de la ventana
    ventana_temp.title('Temperatura')
########################################################################################################################    
def resp():
    etiqueta1.config(text="Usted eligió: Respiración")
    ventana_resp=tk.Tk()
    #Modificamos el tamaño de la ventana (píxeles)
    ventana_resp.geometry('700x700')
    #Cambiamos el nombre de la ventana
    ventana_resp.title('Respiración')
    
def perf():
    etiqueta1.config(text="Usted eligió: Onda de rendimiento")
    ventana_perf=tk.Tk()
    #Modificamos el tamaño de la ventana (píxeles)
    ventana_perf.geometry('700x700')
    #Cambiamos el nombre de la ventana
    ventana_perf.title('Onda de rendimiento')
########################################################################################################################    
def co():
    etiqueta1.config(text="Usted eligió: Gasto cardiaco")
    ventana_co=tk.Tk()
    #Modificamos el tamaño de la ventana (píxeles)
    ventana_co.geometry('700x700')
    #Cambiamos el nombre de la ventana
    ventana_co.title('Señal de salida de gasto cardiaco')
########################################################################################################################    
def bp():
    etiqueta1.config(text="Usted eligió: Presión sanguínea")
    ventana_bp=tk.Tk()
    #Modificamos el tamaño de la ventana (píxeles)
    ventana_bp.geometry('700x700')
    #Cambiamos el nombre de la ventana
    ventana_bp.title('Presión sanguínea')
######################################################################################################################## 
def pace():
    etiqueta1.config(text="Usted eligió: Marcapasos")
    ventana_pace=tk.Tk()
    #Modificamos el tamaño de la ventana (píxeles)
    ventana_pace.geometry('700x700')
    #Cambiamos el nombre de la ventana
    ventana_pace.title('Marcapasos')
########################################################################################################################    
def fema():
    etiqueta1.config(text="Usted eligió: Fetal/Materno")
    ventana_fema=tk.Tk()
    #Modificamos el tamaño de la ventana (píxeles)
    ventana_fema.geometry('700x700')
    #Cambiamos el nombre de la ventana
    ventana_fema.title('Fetal / Materno')
######################################################################################################################## 
def aceptar():
    print("Aceptar")
########################################################################################################################

ECG_onda= ttk.Button(ventana, text='ECG Onda', command=ECG)
ECG_onda.grid(row=1, column=1)
########################################################################################################################
arritmia=ttk.Button(ventana, text='Arritmia', command=arry)
arritmia.grid(row=2, column=1)
########################################################################################################################
temperatura=ttk.Button(ventana, text='Temperatura', command=temp)
temperatura.grid(row=3, column=1)
########################################################################################################################
respiracion=ttk.Button(ventana, text='Respiración', command=resp)
respiracion.grid(row=1, column=2)
########################################################################################################################
onda_de_rendimiento=ttk.Button(ventana, text='Onda de rendimiento', command=perf)
onda_de_rendimiento.grid(row=2, column=2)
########################################################################################################################
gasto_cardiaco=ttk.Button(ventana, text='Gasto cardiaco', command=co)
gasto_cardiaco.grid(row=3, column=2)
########################################################################################################################
presion_sanguinea=ttk.Button(ventana, text='Presión sanguinea', command=bp)
presion_sanguinea.grid(row=1, column=3)
########################################################################################################################
marca_pasos=ttk.Button(ventana, text='Marcapasos', command=pace)
marca_pasos.grid(row=2, column=3)
########################################################################################################################
fetal_materno=ttk.Button(ventana, text='Fetal / Materno', command=fema)
fetal_materno.grid(row=3, column=3)
########################################################################################################################

# Aplicamos el estilo a los botones
ECG_onda.configure(style='TButton')
arritmia.configure(style='TButton')
temperatura.configure(style='TButton')
respiracion.configure(style='TButton')
onda_de_rendimiento.configure(style='TButton')
gasto_cardiaco.configure(style='TButton')
presion_sanguinea.configure(style='TButton')
marca_pasos.configure(style='TButton')
fetal_materno.configure(style='TButton')
########################################################################################################################
# Aplicamos el estilo a las etiquetas
etiqueta1.configure(style='TLabel')
########################################################################################################################
ventana.mainloop()

# %%
import tkinter as tk #Importamos biblioteca tkinter para desarrollo de aplicacicones de escritorio
import tk_tools # pip instal tk-tools
import serial # pip install pyserial 
import numpy as np  #Importamos la biblioteca numpy como np
from matplotlib.figure import Figure  #Importamos la función 'Figure' de matplotlib.figure
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg #interfaz gráfica
from tkinter import ttk

########################################################################################################################

def modo_basico(event=None):
    ventana_modo_basico = tk.Toplevel(ventana) #Creamos una nueva ventana, el argumento es el elemento padre
    ventana_modo_basico.title("Modo básico") # título de interfaz
    ventana_modo_basico.geometry("900x700") # tamaño de interfaz (en píxeles)
    ventana_modo_basico.configure(background="white") # fondo de la interfaz 
    def graficar(): #Creamos una función para graficar nuestros datos
        global condicion, datos   #Generamos dos variables globales (para utilizarlas fuera de la función)

        if condicion == True:  #Si nuestra condición tiene un valor booleano 'TRUE'
            dato=arduino.readline()   #El valor leído de nuestro arduino será asignado a la variable dato
            #dato = '500\n'
            if len(datos) < 100:  #Si la longitud de los datos va de 0 a 99
                datos=np.append(datos, float(dato[0:len(dato)-2]))  #A la variable datos se lea añadirá el elemento del ciclo en el que estemos

            else:  #Si la longitud de los datos es mayor o igual a 100
                datos[0:99]=datos[1:100]  #Reasignamos el valor de las filas 1 a 100  de mi arreglo 'datos' a mis filas 0 a 99
                                            #de mi mismo arreglo 'datos'
                datos[99]=float(dato[0:len(dato)-2])

            linea.set_xdata(np.arange(0,len(datos))) #Generamos el eje x de acuerdo a la longitud de mis datos del arduino
            linea.set_ydata(datos) #Generamos el eje y de acuerdo a la longitud de mi variable 'dato'

            canvas.draw()  #Muestra en pantalla los ejes, y los datos de nuestro arduino

            valor=int(dato[0:len(dato)-2].decode('utf-8')) #Aplicamos formato UTF-8 (Escritura)
            display.set_value(str(valor)) #Muestra en la pantalla el valor que registre mi arduino en Volts

        ventana_modo_basico.after(1,graficar)  #Recursividad


    def iniciar_graficado(): #Generamos una función para iniciar el graficado de mis valores
        global condicion #Llamamos a la variable condición, previamente declarada como variable global
        condicion=True  #Si mi condición tiene un valor booleano como 'True'
        boton_inicio.config(state='disabled') #El botón para iniciar el graficado está deshabilitado por defecto
        boton_detencion.config(state='normal')
        arduino.reset_input_buffer() #Establece la comunicación entre arduino y python

    def detener_graficado(): #Generamos una función para detener el graficado de mis valores
        global condicion   #LLamamos a la variable condición, previamente declarada como variable global
        condicion=False  #Si mi condición tiene un valor booleano como 'True'
        boton_inicio.config(state='normal') #El botón de inicio tiene su configuración por defecto (Establecida previamente)
        boton_detencion.config(state='disabled')  #El botón de detener graficado está deshabilitado por defecto
        arduino.reset_input_buffer() #Establece la comunicación entre arduino y python

    def cerrar():  #Generamos la función para detener la pantalla en ejecución
        arduino.close()   #Cerramos la función del arduino
        ventana_modo_basico.destroy()   #Cierre total



    #GRÁFICA
    fig=Figure(figsize=(8,4), dpi=100)  #Establecemos el tamaño de nuestro espacio para graficar
    ax=fig.add_subplot(111)
    ax.set_title('Señal') #Establecemos el título de la graficadora
    ax.set_xlabel('Tiempo')  #Al eje x establecemos el título de 'Tiempo'
    ax.set_ylabel('Voltaje') #Al eje y establecemos el título de 'Voltaje'
    ax.grid(True,linestyle='-.')  #Establecemos el estilo de linea para graficar
    ax.set_xlim(0,100) #Establecemos límites de espacio para el eje x
    ax.set_ylim(0,1024) #Establecemos límites de espacio para el eje y

    linea=ax.plot([], [], color='green', marker='o', markersize=6)[0]  #Establecemos el color de la línea con el marcador deseado 
    canvas = FigureCanvasTkAgg(fig, master=ventana_modo_basico)  #Generamos el dibujo
    canvas.draw()


    #CONTROLES
    # Constuir objeto botón, padx y pady es pixeles de espacio del componente
    boton_inicio = tk.Button(master= ventana_modo_basico, text="Iniciar Graficado", #Establecemos el texto que tendrá el botón de iniciar graficado
                                  bg="green", fg="white", padx=10, pady=10,  #Será de color verde con letras blancas
                                  command=lambda:iniciar_graficado())  #Cuando lo presionemos iniciará el graficado

    boton_detencion = tk.Button(master= ventana_modo_basico, text="Detener Graficado", #Establecemos el texto que tendrá el botón de detener graficado
                                     bg="red", fg="white", padx=10, pady=10, #Será de color rojo con letras blancas
                                     command=lambda:detener_graficado()) #Cuando lo presionemos se detendrá el graficado

    boton_cerrar = tk.Button(master= ventana_modo_basico, text="Cerrar", #Establecmos el texto que tendrá el botón para cerrar la pantalla de ejecución
                                     bg="gray", fg="white", padx=10, pady=10, #Será de color gris con letras blancas
                                     command=cerrar)  #Cuando lo precionemos se cerrará

    etiqueta = tk.Label(master= ventana_modo_basico, text='Valor del Sensor', bg='white')  #Generamos una etiqueta que diga 'Valor del sensor'
    display = tk_tools.SevenSegmentDigits(ventana_modo_basico, digits=4, background='white', digit_color='black', height=50) #Será de fondo blanco con 
                                                                                                             #números negros
    display.set_value('0')

    #Posicionar mis botones
    canvas.get_tk_widget().grid(row=0, column=0, columnspan=2, rowspan=2, padx=30, pady=30) #Establecemos la posición de mis botones
    boton_inicio.grid(row=3, column=0, pady=20)  #Establezco coordenadas para colocar mi botón de inicio
    boton_detencion.grid(row=3, column=1, pady=20)  #Establezco coordenadas para colocar mi botón de detener graficado
    boton_cerrar.grid(row=4, column=0, columnspan=2) #Va a ocupar dos columnas

    etiqueta.grid(row=2, column=0, pady=10)  #Establezco la posición de mi etiqueta
    display.grid(row=2, column=1, pady=10)

    boton_detencion.config(state='disabled') #El botón de detener graficado por defecto estará deshabilitado
    datos=np.array([]) #Datos será un arreglo de tipo numpy
    condicion=False  #Mi condición en un inicio será un tipo booleano 'False'
    #arduino = serial.Serial('COM5', 9600)  #Mi arduino se encuentra en el puerto 'COM5' e inicio comunicación serial
    ventana_modo_basico.after(1,graficar)  #Comienza el graficado

    ventana_modo_basico.mainloop() # Renderizar el componente
    
'''XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX'''
    
def aceptar():
    print("Aceptar")
    
'''XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX'''
    
def ECG(): #Evento que se hará al elegir Onda ECG
    ventana_ECG = tk.Toplevel(ventana) #Creamos una nueva ventana, el argumento es el elemento padre
    ventana_ECG.geometry('500x500') #Definimos el tamaño de la nueva ventana (en píxeles)
    ventana_ECG.title('ECG onda') #Título de la nueva ventana
    
    aceptar=ttk.Button(ventana_ECG, text='Aceptar')
    aceptar.grid(row=20, column=25)
    
    etiqueta_ECG=ttk.Label(ventana_ECG, text='Tasa ECG (BPM): ')
    etiqueta_amplitud=ttk.Label(ventana_ECG, text='Amplitud (mV): ')
    etiqueta_tipo=ttk.Label(ventana_ECG, text='Tipo (Adulto/Niño): ')
    etiqueta_st=ttk.Label(ventana_ECG, text='ST: ')
    etiqueta_artefacto=ttk.Label(ventana_ECG, text='Artefacto (On/Off): ')
    #///////////////////////////////////////////////////////////////////
    etiqueta_ECG.grid(row=10, column=22, columnspan=2)
    etiqueta_ECG.configure(style='TLabel')
    
    etiqueta_amplitud.grid(row=11, column=22, columnspan=2)
    etiqueta_amplitud.configure(style='TLabel')
    
    etiqueta_tipo.grid(row=12, column=22, columnspan=2)
    etiqueta_tipo.configure(style='TLabel')
    
    etiqueta_st.grid(row=13, column=22, columnspan=2)
    etiqueta_st.configure(style='TLabel')
    
    etiqueta_artefacto.grid(row=14, column=22, columnspan=2)
    etiqueta_artefacto.configure(style='TLabel')
    #///////////////////////////////////////////////////////////////////
    entrada_ECG=ttk.Entry(ventana_ECG, width=40, textvariable='Ingresa los latidos por minuto: ')
    entrada_ECG.grid(row=10, column=25)
    
    entrada_amplitud=ttk.Entry(ventana_ECG, width=40, textvariable='Ingresa la amplitud: ')
    entrada_amplitud.grid(row=11, column=25)
    
    entrada_tipo=ttk.Entry(ventana_ECG, width=40, textvariable='Ingresa el tipo: ')
    entrada_tipo.grid(row=12, column=25)
    
    entrada_st=ttk.Entry(ventana_ECG, width=40, textvariable='Ingresa el ST: ')
    entrada_st.grid(row=13, column=25)
    
    entrada_artefacto=ttk.Entry(ventana_ECG, width=40, textvariable='Ingresa el artefacto: ')
    entrada_artefacto.grid(row=14, column=25)

'''XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX'''    
    
def bp(): #Evento que se hará al elegir presión sanguínea
    ventana_bp=tk.Toplevel(ventana)  #Creamos una nueva ventana, el argumento es el elemento padre
    ventana_bp.geometry('500x500') #Definimos el tamaño de la nueva ventana (en píxeles)
    ventana_bp.title('Presión sanguínea') #Título de la nueva ventana
    aceptar=ttk.Button(ventana_bp, text='Aceptar')
    aceptar.grid(row=20, column=25)
    
    etiqueta_1=ttk.Label(ventana_bp, text='Etiqueta 1: ')
    etiqueta_2=ttk.Label(ventana_bp, text='Etiqueta 2: ')
    etiqueta_3=ttk.Label(ventana_bp, text='Etiqueta 3: ')
    etiqueta_4=ttk.Label(ventana_bp, text='Etiqueta 4: ')
    etiqueta_5=ttk.Label(ventana_bp, text='Etiqueta 5: ')
    #///////////////////////////////////////////////////////////////////
    etiqueta_1.grid(row=10, column=22, columnspan=2)
    etiqueta_1.configure(style='TLabel')
    
    etiqueta_2.grid(row=11, column=22, columnspan=2)
    etiqueta_2.configure(style='TLabel')
    
    etiqueta_3.grid(row=12, column=22, columnspan=2)
    etiqueta_3.configure(style='TLabel')
    
    etiqueta_4.grid(row=13, column=22, columnspan=2)
    etiqueta_4.configure(style='TLabel')
    
    etiqueta_5.grid(row=14, column=22, columnspan=2)
    etiqueta_5.configure(style='TLabel')
    #///////////////////////////////////////////////////////////////////
    entrada_1=ttk.Entry(ventana_bp, width=40, textvariable='Etiqueta 1: ')
    entrada_1.grid(row=10, column=25)
    
    entrada_2=ttk.Entry(ventana_bp, width=40, textvariable='Etiqueta 2: ')
    entrada_2.grid(row=11, column=25)
    
    entrada_3=ttk.Entry(ventana_bp, width=40, textvariable='Etiqueta 3: ')
    entrada_3.grid(row=12, column=25)
    
    entrada_4=ttk.Entry(ventana_bp, width=40, textvariable='Etiqueta 4: ')
    entrada_4.grid(row=13, column=25)
    
    entrada_5=ttk.Entry(ventana_bp, width=40, textvariable='Etiqueta 5: ')
    entrada_5.grid(row=14, column=25)
    
'''XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX'''
    
def temp(): #Evento que se hará al elegir temperatura
    ventana_temp=tk.Toplevel(ventana)  #Creamos una nueva ventana, el argumento es el elemento padre
    ventana_temp.geometry('500x500') #Definimos el tamaño de la nueva ventana (en píxeles)
    ventana_temp.title('Temperatura') #Título de la nueva ventana
    aceptar=ttk.Button(ventana_temp, text='Aceptar')
    aceptar.grid(row=20, column=25)
    
    etiqueta_temperatura=ttk.Label(ventana_temp, text='Ingresa la temperatura: ')
    #///////////////////////////////////////////////////////////////////
    etiqueta_temperatura.grid(row=10, column=22, columnspan=2)
    etiqueta_temperatura.configure(style='TLabel')
    #///////////////////////////////////////////////////////////////////
    entrada_temperatura=ttk.Entry(ventana_temp, width=40, textvariable='Temperatura: ')
    entrada_temperatura.grid(row=10, column=25)
        
########################################################################################################################

ventana = tk.Tk() #Creamos la ventana para que el usuario pueda visualizar opciones
ventana.title("Menú principal")  #Mostramos al usuario que se encuentra en el menu principal
ventana.config(width=300, height=300)  #Ajustes para el tamaño de la ventana
ventana.iconbitmap('C:/Users/josea/Documents/Servicio social/ProSim2.ico') #Logo de la ventana

barra_menus = tk.Menu()  #Creeamos un objeto de la clase menu y se lo asignamos a la variable (menu deslizable)
#Este será el contenedor de todos los menús de la ventana
menu_modos = tk.Menu(barra_menus, tearoff=False) #El primer argumenta indica que estará contenido en barra_menus
#El segundo argumento evita que se pueda mover.

menu_modos.add_command( #Agregamos un comando al menú deslizable
    label="Modo básico",  #Agregamos una étiqueta que haga referencia al modo básico
    command=modo_basico,   #Esto sucederá si le damos click
    compound=tk.LEFT      #Si un ícono está presente, se colocará a la izquierda del texto
)
menu_modos.add_separator()  #Añade un separador (literalmente una línea que los separa)

#menu_archivo.add_command(label="Salir", command=ventana.destroy)

opciones_modo_avanzado=tk.Menu(barra_menus, tearoff=False) #Creamos el menu desplegable (objeto) para el modo avanzado
#Estará en el contenedor barra_menus
opciones_modo_avanzado.add_command( #Agregamos un comando al menú deslizable
    label="Onda ECG", #Agregamos una étiqueta que haga referencia a la onda ECG
    command=ECG,  #Esto sucederá si le damos click
    compound=tk.LEFT #Si un ícono está presente, se colocará a la izquierda del texto
)
opciones_modo_avanzado.add_separator()  #Añade un separador (literalmente una línea que los separa)
opciones_modo_avanzado.add_command( #Agregamos un comando al menú deslizable
    label="Presión sanguínea", #Agregamos una étiqueta que haga referencia a la opción "Presión sanguínea"
    command=bp, #Esto sucederá si le damos click
    compound=tk.LEFT #Si un ícono está presente, se colocará a la izquierda del texto
)
opciones_modo_avanzado.add_separator()  #Añade un separador (literalmente una línea que los separa)
opciones_modo_avanzado.add_command( #Agregamos un comando al menú deslizable
    label="Temperatura",  #Agregamos una étiqueta que haga referencia a la opción "Temperatura"
    command=temp, #Esto sucederá si le damos click
    compound=tk.LEFT #Si un ícono está presente, se colocará a la izquierda del texto
)

menu_modos.add_cascade(menu=opciones_modo_avanzado, label="Modo avanzado") #Agregamos la opción de "Modo avanzado" al menú deslizable
barra_menus.add_cascade(menu=menu_modos, label="ProSim2")  #Agregamos un menu desplegable representado por el objeto 'menu_modos'
#El menú será mostrado al usuario como "ProSim2"

ventana.config(menu=barra_menus) #Mostramos el menú al usuario en la ventana principal
ventana.mainloop() #Lo hacemos cíclico

#https://recursospython.com/guias-y-manuales/barra-de-menu-tkinter/
#https://es.stackoverflow.com/questions/427565/env%C3%ADo-recepci%C3%B3n-de-datos-puerto-serie-por-python
